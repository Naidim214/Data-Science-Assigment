# %%
pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      --------------------------------------- 0.0/11.9 MB 186.2 kB/s eta 0:01:04
#      --------------------------------------- 0.0/11.9 MB 186.2 kB/s eta 0:01:04
#      --------------------------------------- 0.1/11.9 MB 252.2 kB/s eta 0:00:47
#      --------------------------------------- 0.1/11.9 MB 308.0 kB/s eta 0:00:39
#      --------------------------------------- 0.1/11.9 MB 379.3 kB/s eta 0:00:31
#       -------------------------------------- 0.2/11.9 MB 455.1 kB/s eta 0:00:26
#       -------------------------------------- 0.2/11.9 MB 529.7 kB/s eta 0:00:22
#       -------------------------------------- 0.3/11.9 MB 610.3 kB/s eta 0:00:19
#      - ------------------------------------- 0.4/11.9 MB 696.3 kB/s eta 0:00:17
# ...

# %%
import pandas as pd
import mysql.connector

# Establish the connection
connection = mysql.connector.connect(host="127.0.0.1:3306",user="root",password="nadim214",database="travel_planner")

# Query the data
query = "SELECT * FROM bookings"
bookings_df = pd.read_sql(query, connection)

# Show the output
print(bookings_df)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\mysql\connector\network.py:482, in MySQLTCPSocket.open_connection(self)
#     481 try:
# --> 482     addrinfos = socket.getaddrinfo(self.server_host,
#     483                                    self.server_port,
#     484                                    0, socket.SOCK_STREAM,
#     485                                    socket.SOL_TCP)
#     486     # If multiple results we favor IPv4, unless IPv6 was forced.
#
# File ~\anaconda3\Lib\socket.py:964, in getaddrinfo(host, port, family, type, proto, flags)
#     963 addrlist = []
# --> 964 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     965     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# ...
